# %% [markdown]
# # CosmoFlow profiling
# - 16 Epochs
# - Runs on Summit
# - Data collected for each rank w/ NSight Systems

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import DataSet
from textwrap import wrap
import seaborn as sns


# Load the data
files = [
    "/ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/1_nodes_batchsize_1_j923942/profiling_results/",
    "/ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/",
    "/ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/",
    "/ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/",
    "/ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/"]

d = DataSet.DataSet()
for f in files:
    d.parseInput(f)
# Out:
# /ccs/home/mrowan/.conda/envs/py37/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/1_nodes_batchsize_1_j923942/profiling_results/nsys.923942.r0.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/1_nodes_batchsize_1_j923942/profiling_results/nsys.923942.r2.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/1_nodes_batchsize_1_j923942/profiling_results/nsys.923942.r5.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/1_nodes_batchsize_1_j923942/profiling_results/nsys.923942.r3.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/1_nodes_batchsize_1_j923942/profiling_results/nsys.923942.r1.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/1_nodes_batchsize_1_j923942/profiling_results/nsys.923942.r4.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r3.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r9.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r6.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r8.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r10.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r11.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r0.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r5.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r4.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r1.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r7.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/2_nodes_batchsize_1_j923943/profiling_results/nsys.923943.r2.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r2.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r4.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r9.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r13.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r6.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r18.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r16.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r1.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r20.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r17.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r7.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r22.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r19.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r10.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r5.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r8.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r23.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r21.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r15.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r12.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r0.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r11.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r3.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/4_nodes_batchsize_1_j923944/profiling_results/nsys.923944.r14.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r17.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r12.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r39.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r18.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r38.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r22.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r6.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r33.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r1.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r16.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r27.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r2.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r19.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r25.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r35.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r37.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r10.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r5.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r43.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r26.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r30.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r7.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r8.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r11.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r34.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r44.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r40.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r23.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r47.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r29.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r32.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r14.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r0.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r42.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r21.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r41.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r20.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r45.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r46.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r4.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r28.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r36.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r31.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r24.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r15.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r9.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r13.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/8_nodes_batchsize_1_j923945/profiling_results/nsys.923945.r3.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r27.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r25.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r46.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r63.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r66.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r92.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r17.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r1.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r30.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r23.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r10.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r14.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r15.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r31.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r5.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r43.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r38.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r85.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r40.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r60.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r21.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r11.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r71.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r49.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r33.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r70.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r45.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r2.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r8.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r24.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r65.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r78.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r57.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r94.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r42.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r93.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r73.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r90.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r80.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r22.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r95.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r89.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r58.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r26.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r74.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r29.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r62.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r64.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r56.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r83.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r35.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r87.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r69.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r48.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r77.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r54.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r9.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r4.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r67.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r86.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r16.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r20.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r47.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r91.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r39.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r59.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r34.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r44.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r12.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r75.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r50.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r76.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r18.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r53.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r3.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r55.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r81.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r72.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r79.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r28.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r19.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r88.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r84.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r32.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r52.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r82.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r37.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r13.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r41.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r68.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r0.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r61.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r36.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r7.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r51.w.txt
# Parsing /ccs/home/mrowan/scratch/ml-performance-benchmark/cosmoflow/summit/results/16_nodes_batchsize_1_j923946/profiling_results/nsys.923946.r6.w.txt

# %% [markdown]
# ## Plotting preferences

# %%
golden = 1.61803398875
figWidth = 5. # inches
figLength = figWidth/golden
figSize1x1 = (figWidth, figLength)

rcParams['font.sans-serif'] = 'Arial'
rcParams['font.family'] = 'sans-serif'
rcParams['mathtext.fontset'] = 'custom'
rcParams['mathtext.rm'] = 'Arial'
rcParams['mathtext.it'] = 'Arial:italic'
rcParams['mathtext.bf'] = 'Arial:bold'
rcParams['axes.labelsize'] = '12'
rcParams['xtick.labelsize'] = '12'
rcParams['ytick.labelsize'] = '12'
rcParams['legend.labelspacing'] = '0.1'
rcParams['xtick.direction'] = 'in'
rcParams['ytick.direction'] = 'in'
rcParams['ytick.right'] = True
rcParams['xtick.top'] = True
rcParams['axes.linewidth'] = 2.0
rcParams['xtick.major.size'] = 3.5
rcParams['xtick.major.width'] = 1.5
rcParams['xtick.minor.size'] = 2.5
rcParams['xtick.minor.width'] = 1.0
rcParams['ytick.major.size'] = 3.5
rcParams['ytick.major.width'] = 1.5
rcParams['ytick.minor.size'] = 2.5
rcParams['ytick.minor.width'] = 1.0
rcParams['lines.markersize'] = 7
rcParams['lines.linewidth'] = 1.5

markers1 = np.array(['o', '^', 's', 'x', 'd', 'v'])
markers2 = np.array(['s', 'o', 'x', '*'])
# Other options: Dark2, Pastel1, Pastel2, Accent,
# Set1, Set2, Set3, tab10, tab20, tab20b, tab20c
colors = sns.color_palette('muted') + sns.color_palette('dark',)

# %% [markdown]
# ## GPU Kernel Time

# %%
nRoutines = 7
all_nodes = sorted(list(d._hash.keys())[1:],key=lambda x:int(x.replace('_nodes', '')))#
#all_nodes = list(d._hash.keys())[1:]
ranksPerNodeSummit = 6
nRanks = np.array([ranksPerNodeSummit*int(x.split('_')[0]) for x in all_nodes])
# Note 1_node and >1_node case has different routines, so can't compare exactly
expensiveRoutines = d['2_nodes']['r0']['gpukernsum']['Name'][:nRoutines].values

# Compare raw times
fig, axs = plt.subplots(nrows=1, ncols=nRoutines, sharey=True, figsize=(14, 2.))
plt.suptitle('GPU Kernel Time', y=1.4, fontsize=20)
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).sum() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - nRanks*np.array(expensiveRoutineTimesMin), 
                                         nRanks*np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)), fontsize='8')
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Total time (ns)\n (summed over ranks)')
    
fig.subplots_adjust(wspace=0.1)
plt.savefig('figs/GPU_Kernel_Time_ns.png', dpi=150, bbox_inches='tight')

# Compare % times
fig, axs = plt.subplots(nrows=1, ncols=nRoutines, sharey=True, figsize=(14, 2.))
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).mean() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - np.array(expensiveRoutineTimesMin), 
                                         np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)), fontsize='8')
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Time(%)\n (average over ranks)')
    
fig.subplots_adjust(wspace=0.1)
plt.savefig('figs/GPU_Kernel_Time_Percent.png', dpi=150, bbox_inches='tight')

# Compare # instances
fig, axs = plt.subplots(nrows=1, ncols=len(expensiveRoutines), sharey='none', figsize=(18, 2.))
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Instances'])
                                             for r in d[nodes].keys()] ).sum() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Instances'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['gpukernsum'].loc[d[nodes][r]['gpukernsum']['Name'] == routine]['Instances'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - nRanks*np.array(expensiveRoutineTimesMin), 
                                         nRanks*np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)), fontsize='8')
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Number of instances\n (sum over ranks)')
    
fig.subplots_adjust(wspace=0.6)
plt.savefig('figs/GPU_Kernel_Instances.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ## GPU Mem Time

# %%
all_nodes = sorted(list(d._hash.keys())[1:],key=lambda x:int(x.replace('_nodes', '')))
ranksPerNodeSummit = 6
nRanks = np.array([ranksPerNodeSummit*int(x.split('_')[0]) for x in all_nodes])
expensiveRoutines = d['1_nodes']['r0']['gpumemtimesum']['Operation'].values

# Compare raw times
fig, axs = plt.subplots(nrows=1, ncols=len(expensiveRoutines), sharey=True, figsize=(14, 2.))
plt.suptitle('GPU Mem Time', y=1.25, fontsize=20)
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).sum() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - nRanks*np.array(expensiveRoutineTimesMin), 
                                         nRanks*np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)))
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Total time (ns)\n (summed over ranks)')
    
fig.subplots_adjust(wspace=0.1)
plt.savefig('figs/GPU_Mem_Time_ns.png', dpi=150, bbox_inches='tight')

# Compare % times
fig, axs = plt.subplots(nrows=1, ncols=len(expensiveRoutines), sharey=True, figsize=(14, 2.))
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).mean() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - np.array(expensiveRoutineTimesMin), 
                                         np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)))
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Time(%)\n (average over ranks)')
    
fig.subplots_adjust(wspace=0.1)
plt.savefig('figs/GPU_Mem_Time_Percent.png', dpi=150, bbox_inches='tight')

# Compare # instances
fig, axs = plt.subplots(nrows=1, ncols=len(expensiveRoutines), sharey=True, figsize=(14, 2.))
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Operations'])
                                             for r in d[nodes].keys()] ).sum() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Operations'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['gpumemtimesum'].loc[d[nodes][r]['gpumemtimesum']['Operation'] == routine]['Operations'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - nRanks*np.array(expensiveRoutineTimesMin), 
                                         nRanks*np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)))
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Number of instances\n (sum over ranks)')
    
fig.subplots_adjust(wspace=0.1)
plt.savefig('figs/GPU_Mem_Instances.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ## CUDA API Time

# %%
nRoutines = 7
all_nodes = sorted(list(d._hash.keys())[1:],key=lambda x:int(x.replace('_nodes', '')))#
ranksPerNodeSummit = 6
nRanks = np.array([ranksPerNodeSummit*int(x.split('_')[0]) for x in all_nodes])
# Note 1_node and >1_node case has different routines, so can't compare exactly
expensiveRoutines = d['1_nodes']['r0']['cudaapisum']['Name'][:nRoutines].values

# Compare raw times
fig, axs = plt.subplots(nrows=1, ncols=nRoutines, sharey=True, figsize=(14, 2.))
plt.suptitle('CUDA API Time', y=1.3, fontsize=20)
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).sum() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Total Time (ns)'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - nRanks*np.array(expensiveRoutineTimesMin), 
                                         nRanks*np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)), fontsize='11')
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Total time (ns)\n (summed over ranks)')
    
fig.subplots_adjust(wspace=0.1)
plt.savefig('figs/CUDA_API_Time_ns.png', dpi=150, bbox_inches='tight')

# Compare % times
fig, axs = plt.subplots(nrows=1, ncols=nRoutines, sharey=True, figsize=(14, 2.))
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).mean() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Time(%)'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - np.array(expensiveRoutineTimesMin), 
                                         np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)), fontsize='11')
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Time(%)\n (average over ranks)')
    
fig.subplots_adjust(wspace=0.1)
plt.savefig('figs/CUDA_API_Time_Percent.png', dpi=150, bbox_inches='tight')

# Compare # instances
fig, axs = plt.subplots(nrows=1, ncols=len(expensiveRoutines), sharey='none', figsize=(18, 2.))
for i, routine in enumerate(expensiveRoutines):
    expensiveRoutineTimesSum = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Num Calls'])
                                             for r in d[nodes].keys()] ).sum() for nodes in all_nodes]
    expensiveRoutineTimesMin = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Num Calls'])
                                             for r in d[nodes].keys()] ).min() for nodes in all_nodes] 
    expensiveRoutineTimesMax = [ np.array( [np.array(d[nodes][r]['cudaapisum'].loc[d[nodes][r]['cudaapisum']['Name'] == routine]['Num Calls'])
                                             for r in d[nodes].keys()] ).max() for nodes in all_nodes]
    yerrs = np.array([err for err in zip(np.array(expensiveRoutineTimesSum) - nRanks*np.array(expensiveRoutineTimesMin), 
                                         nRanks*np.array(expensiveRoutineTimesMax) - np.array(expensiveRoutineTimesSum))]).T
    
    plt.sca(axs.flatten()[i])
    plt.gca().set_title("\n".join(wrap(routine, 22)))
    plt.gca().title.set_y(1.1)
    plt.bar(all_nodes, expensiveRoutineTimesSum, color=colors[0], 
            yerr=yerrs, edgecolor='k',
           capsize=4, zorder=5, ecolor='k')
    plt.gca().yaxis.grid(True)

    plt.xticks(rotation=-30, ha="left", rotation_mode="anchor")
    if i==0: plt.ylabel('Number of instances\n (sum over ranks)')
    
#plt.tight_layout()
fig.subplots_adjust(wspace=0.6)
plt.savefig('figs/CUDA_API_Instances.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ## GPU Kernel Time vs. GPU Mem Time for nodes

# %%
all_nodes = sorted(list(d._hash.keys())[1:],key=lambda x:int(x.replace('_nodes', '')))#

#ranksPerNodeSummit = 6
#nRanks = np.array([ranksPerNodeSummit*int(x.split('_')[0]) for x in all_nodes])
gpukerntime = [ sum([d[nodes][r]['gpukernsum']['Total Time (ns)'].sum() 
                    for r in d[nodes].keys()]) for nodes in all_nodes]
gpumemtime = [ sum([d[nodes][r]['gpumemtimesum']['Total Time (ns)'].sum() 
                    for r in d[nodes].keys()]) for nodes in all_nodes]
cudaapitime = [ sum([d[nodes][r]['cudaapisum']['Total Time (ns)'].sum() 
                    for r in d[nodes].keys()]) for nodes in all_nodes]
      
plt.ion()
plt.figure(figsize=figSize1x1)
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = gpukerntime
bars2 = cudaapitime
bars3 = gpumemtime
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + 2*barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color=colors[0], width=barWidth, edgecolor='k', label='GPU kernel time')
plt.bar(r2, bars2, color=colors[1], width=barWidth, edgecolor='k', label='CUDA API time')
plt.bar(r3, bars3, color=colors[2], width=barWidth, edgecolor='k', label='GPU mem time')
     
plt.ylabel('Total time (ns)\n (summed over ranks)')
#plt.ylim(0, 3.2e12)
plt.xticks([r + 0.5*barWidth for r in range(len(bars1))], all_nodes);

plt.legend(loc=2)
plt.tight_layout()
plt.savefig('figs/Time_vs_Nodes.png', dpi=150, bbox_inches='tight')
