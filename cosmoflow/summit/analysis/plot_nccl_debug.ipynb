# %% [markdown]
# # CosmoFlow NCCL profiling
# - 5 Epochs
# - Runs on Summit
# - Batch size 1
# - Horovod, NCCL backend
# - Data collected for each rank w/ NCCL_DEBUG flags

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams
import DataSet
from textwrap import wrap
import seaborn as sns
from collections import Counter

# Load the data
files = ['../results/8_nodes_batchsize_1_j937045/nccl_logs/']

d = DataSet.DataSet()
for f in files:
    d.parseInput(f, inputType='nccl')
# Out:
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r14.w ; 14 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r9.w ; 9 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r25.w ; 25 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r21.w ; 21 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r43.w ; 43 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r2.w ; 2 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r27.w ; 27 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r15.w ; 15 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r16.w ; 16 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r24.w ; 24 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r46.w ; 46 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r26.w ; 26 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r7.w ; 7 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r6.w ; 6 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r31.w ; 31 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r30.w ; 30 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r32.w ; 32 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r13.w ; 13 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r47.w ; 47 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r17.w ; 17 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r29.w ; 29 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r8.w ; 8 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r3.w ; 3 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r36.w ; 36 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r1.w ; 1 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r5.w ; 5 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r39.w ; 39 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r35.w ; 35 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r11.w ; 11 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r23.w ; 23 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r42.w ; 42 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r34.w ; 34 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r18.w ; 18 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r10.w ; 10 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r41.w ; 41 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r37.w ; 37 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r33.w ; 33 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r12.w ; 12 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r0.w ; 0 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r40.w ; 40 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r45.w ; 45 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r19.w ; 19 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r22.w ; 22 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r44.w ; 44 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r28.w ; 28 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r20.w ; 20 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r38.w ; 38 rank, 8 nodes
# Parsing ../results/8_nodes_batchsize_1_j937045/nccl_logs/nccl.937045.r4.w ; 4 rank, 8 nodes

# %% [markdown]
# ## Plotting preferences

# %%
golden = 1.61803398875
figWidth = 5. # inches
figLength = figWidth/golden
figSize1x1 = (figWidth, figLength)

rcParams['font.sans-serif'] = 'Arial'
rcParams['font.family'] = 'sans-serif'
rcParams['mathtext.fontset'] = 'custom'
rcParams['mathtext.rm'] = 'Arial'
rcParams['mathtext.it'] = 'Arial:italic'
rcParams['mathtext.bf'] = 'Arial:bold'
rcParams['axes.labelsize'] = '12'
rcParams['xtick.labelsize'] = '12'
rcParams['ytick.labelsize'] = '12'
rcParams['legend.labelspacing'] = '0.1'
rcParams['xtick.direction'] = 'in'
rcParams['ytick.direction'] = 'in'
rcParams['ytick.right'] = True
rcParams['xtick.top'] = True
rcParams['axes.linewidth'] = 2.0
rcParams['xtick.major.size'] = 3.5
rcParams['xtick.major.width'] = 1.5
rcParams['xtick.minor.size'] = 2.5
rcParams['xtick.minor.width'] = 1.0
rcParams['ytick.major.size'] = 3.5
rcParams['ytick.major.width'] = 1.5
rcParams['ytick.minor.size'] = 2.5
rcParams['ytick.minor.width'] = 1.0
rcParams['lines.markersize'] = 7
rcParams['lines.linewidth'] = 1.5

markers1 = np.array(['o', '^', 's', 'x', 'd', 'v'])
markers2 = np.array(['s', 'o', 'x', '*'])
# Other options: Dark2, Pastel1, Pastel2, Accent,
# Set1, Set2, Set3, tab10, tab20, tab20b, tab20c
colors = sns.color_palette('muted') + sns.color_palette('dark',)

# %% [markdown]
# ## NCCL AllReduce histogram

# %%
# data collected for 8 node runs
ranks = sorted(d._hash[8].keys())
op, datatype = 'ncclSum', 'ncclFloat32'

fig, axs = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(8, 6.))
plt.suptitle('NCCL AllReduce invocations vs. count\n'
             +'op: {}, datatype: {}'.format(op, datatype), y=1.1, fontsize=20)

# 4 Bytes * count
nbytes = np.array(4*d._hash[8][0][op][datatype])
nbytes_to_count = Counter(nbytes)

# MegaBytes
x = np.array(list(nbytes_to_count.keys()))
y = np.array([nbytes_to_count[nb] for nb in x])

# Plot MegaBytes vs. Count
plt.sca(axs.flatten()[0])
plt.scatter(x/10.**6, y, color=colors[0], marker='o',
            facecolor=mpl.colors.ColorConverter().to_rgba(colors[0], alpha=0.5),
            edgecolor=mpl.colors.ColorConverter().to_rgba('k', alpha=1.0), zorder=5)
plt.ylim(-100, 1400)
plt.gca().yaxis.grid(True)
plt.ylabel('Number of invocations')


# Plot MegaBytes vs. Count
plt.sca(axs.flatten()[1])
plt.hist(nbytes/10.**6, bins=100, color=colors[0], edgecolor='k', zorder=5)
plt.ylim(-100, 1400)
plt.gca().yaxis.grid(True)
plt.xlabel('ncclAllReduce buffer size (MB)')
plt.ylabel('Number of invocations')
plt.tight_layout()

plt.savefig('figs/NCCL_count.png', dpi=150, bbox_inches='tight')
